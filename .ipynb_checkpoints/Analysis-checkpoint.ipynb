# %%
import os
import pandas as pd

# %%
all_data = pd.read_excel(r'/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Vente/All_data_clean.xlsx')
all_data.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0    Villa sur prestigia 570m² ville verte bouskoura
# 1           1            Appartement 132m² aux portes californie
# 2           2  Appartement de 122m² en vente, Le Prestige Cal...
# 3           3  Top affaire magnifique villa a vendre a Agdal ...
# 4           4     Les deux appartements à vendre à Hay Al Riyadh
#
#                         Location         Price  \
# 0                      Bouskoura  7 800 000 DH
# 1  Quartier Bachkou à Casablanca  1 730 000 DH
# 2        Californie à Casablanca  1 712 000 DH
# 3      Route Amizmiz à Marrakech  2 990 000 DH
# 4                  Riyad à Rabat  2 300 000 DH
#
#                                     Caractéristiques  \
# 0  ['Jardin', 'Terrasse', 'Garage', 'Piscine', 'C...
# 1  ['Jardin', 'Garage', 'Ascenseur', 'Salon Maroc...
# 2       ['Climatisation', 'Cuisine équipée', 'Four']
# 3                  ['Jardin', 'Terrasse', 'Piscine']
# ...

# %%
# all_data['City'] = all_data['Location'].str.split("à")
# all_data['City'] = all_data['Location'].str.split(",")
# try :
#     all_data['City'] = all_data['Location'].apply(lambda x: x.split("à")[1:2])
# except :
#     all_data['City'] = all_data['Location'].apply(lambda x: x.split("à")[:1])
    
# all_data

# %%
# all_data['City'] = (
#     all_data['City'] 
#     .transform(
#         lambda x: ",".join(map(str,x))    
#     )
# )
# all_data

# %%
# a=all_data['City']==''
# a.sum()
# # if all_data['City']=='':
# #     all_data['City'] = all_data['Location'].apply(lambda x: x.split("à")[:1])
# while all_data['City']=='':
#     all_data['City'] = all_data['Location'].apply(lambda x: x.split("à")[:1])
# all_data['City']

# %%
# all_data['City2'] = all_data['Location'].apply(lambda x: x.split("à")[:1])
# # all_data['doddo'] = all_data['City'] + all_data['City2']
# # all_data
# all_data

# %%
# all_data['City2'] = (
#     all_data['City2'] 
#     .transform(
#         lambda x: ",".join(map(str,x))    
#     )
# )
# all_data

# %%
# all_data['dodo'] = all_data['City2'] +' '+all_data['City']
# all_data

# %%
# all_data['aa'] = all_data['dodo'].apply(lambda x: x.split(" ")[0])
# all_data

# %%
# all_data.to_excel("/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Vente/clean.xlsx")

# %%
# import numpy as pd
# b = all_data['Location'].apply(lambda x: x.split("à")[:1])
# all_data['City'] = all_data['City'].replace(r'',a, regex=True)

# all_data

# %%
# all_data['City'] = all_data['City'].replace(r'', np.nan, regex=True)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1881 entries, 0 to 1880
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1881 non-null   int64
#  1   Title             1881 non-null   object
#  2   Location          1881 non-null   object
#  3   Price             1881 non-null   object
#  4   Caractéristiques  1881 non-null   object
#  5   Pieces            1881 non-null   object
#  6   Description       1881 non-null   object
#  7   Pictures          1881 non-null   object
#  8   Télephone         1881 non-null   object
#  9   Surface           1881 non-null   object
#  10  City              1881 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 161.8+ KB

# %%
# pd.to_numeric(all_data['Price'], errors='ignore')
# all_data['Price']

# %%
all_data['City'] = all_data['City'].str.replace(' ', '')

# %%
all_data.dtypes
# Out:
# Unnamed: 0           int64
# Title               object
# Location            object
# Price               object
# Caractéristiques    object
# Pieces              object
# Description         object
# Pictures            object
# Télephone           object
# Surface             object
# City                object
# dtype: object

# %%
all_data['Prix']=all_data['Price']
all_data.drop(all_data[all_data['Prix'] == 'notdefined'].index, inplace = True)
all_data.drop(all_data[all_data['Prix'] == 'not defined'].index, inplace = True)
all_data['Prix'] = all_data['Prix'].str.replace(r' DH','', regex=True)
all_data['Prix'] = all_data['Prix'].str.replace(r' EUR','', regex=True)
all_data['Prix'] = all_data['Prix'].str.replace(r' USD','', regex=True)

all_data['Prix']
# Out:
# 0       7 800 000
# 1       1 730 000
# 2       1 712 000
# 3       2 990 000
# 4       2 300 000
#           ...
# 1871    7 000 000
# 1872      350 000
# 1874    2 400 000
# 1875    1 700 000
# 1878    1 120 000
# Name: Prix, Length: 1593, dtype: object

# %%
# # all_data['Price'] = all_data['Price'].str.replace(r' \x','', regex=True)
all_data['Prix'] = all_data['Prix'].str.replace('\xa0', '')
all_data['Prix'] = all_data['Prix'].astype('int64')
all_data['Prix']
# all_data['Price'].astype(str).astype(int)
# all_data['Price'] = int(all_data['Price'])
# Out:
# 0       7800000
# 1       1730000
# 2       1712000
# 3       2990000
# 4       2300000
#          ...
# 1871    7000000
# 1872     350000
# 1874    2400000
# 1875    1700000
# 1878    1120000
# Name: Prix, Length: 1593, dtype: int64

# %%
all_data['outside'] = all_data['Surface']
all_data['outside'] = all_data['outside'].str.replace(r'm²','', regex=True)
all_data['outside'] = all_data['outside'].str.replace(r'Nouveau','', regex=True)

all_data['outside'] = all_data['outside'].str.replace(r'h0h0h0h0h0h0h0h','', regex=True)

# # all_data['Surface'] = all_data['Surface'].str.replace('', 'h')
# pd.to_numeric(all_data['Surface'], downcast='float')
# all_data['Surface'] = all_data['Surface'].astype('str').astype('float').astype('int64')

# all_data['Surface']

# %%
all_data.drop(all_data[all_data['outside'] == ''].index, inplace = True)
all_data.drop(all_data[all_data['outside'] == ' '].index, inplace = True)

all_data
# Out:
#       Unnamed: 0                                              Title  \
# 0              0    Villa sur prestigia 570m² ville verte bouskoura
# 1              1            Appartement 132m² aux portes californie
# 2              2  Appartement de 122m² en vente, Le Prestige Cal...
# 3              3  Top affaire magnifique villa a vendre a Agdal ...
# 4              4     Les deux appartements à vendre à Hay Al Riyadh
# ...          ...                                                ...
# 1871         617                          Villa de luxe Dar Bouazza
# 1872         618             Appartement meublée alliance bab sebta
# 1874         620                   Appartement à 50 m des Sœurettes
# 1875         621               Opportunité à saisir sur Dar Bouazza
# 1878         624                    Vente appartement haut standing
#
#                            Location         Price  \
# 0                         Bouskoura  7 800 000 DH
# ...

# %%
all_data['outside'] = all_data['outside'].astype('int64')
all_data['outside']
# Out:
# 0       570
# 1       132
# 2       122
# 3       250
# 4       135
#        ...
# 1871    609
# 1872     56
# 1874    126
# 1875    161
# 1878     95
# Name: outside, Length: 1591, dtype: int64

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1878
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1591 non-null   int64
#  1   Title             1591 non-null   object
#  2   Location          1591 non-null   object
#  3   Price             1591 non-null   object
#  4   Caractéristiques  1591 non-null   object
#  5   Pieces            1591 non-null   object
#  6   Description       1591 non-null   object
#  7   Pictures          1591 non-null   object
#  8   Télephone         1591 non-null   object
#  9   Surface           1591 non-null   object
#  10  City              1591 non-null   object
#  11  Prix              1591 non-null   int64
#  12  outside           1591 non-null   int64
# dtypes: int64(3), object(10)
# memory usage: 174.0+ KB

# %%
all_data
# Out:
#       Unnamed: 0                                              Title  \
# 0              0    Villa sur prestigia 570m² ville verte bouskoura
# 1              1            Appartement 132m² aux portes californie
# 2              2  Appartement de 122m² en vente, Le Prestige Cal...
# 3              3  Top affaire magnifique villa a vendre a Agdal ...
# 4              4     Les deux appartements à vendre à Hay Al Riyadh
# ...          ...                                                ...
# 1871         617                          Villa de luxe Dar Bouazza
# 1872         618             Appartement meublée alliance bab sebta
# 1874         620                   Appartement à 50 m des Sœurettes
# 1875         621               Opportunité à saisir sur Dar Bouazza
# 1878         624                    Vente appartement haut standing
#
#                            Location         Price  \
# 0                         Bouskoura  7 800 000 DH
# ...

# %%
all_data['Price/Surface']=all_data['Prix'] / all_data['outside']

all_data['Price/Surface'] = all_data['Price/Surface'].astype('int64')

all_data
# Out:
#       Unnamed: 0                                              Title  \
# 0              0    Villa sur prestigia 570m² ville verte bouskoura
# 1              1            Appartement 132m² aux portes californie
# 2              2  Appartement de 122m² en vente, Le Prestige Cal...
# 3              3  Top affaire magnifique villa a vendre a Agdal ...
# 4              4     Les deux appartements à vendre à Hay Al Riyadh
# ...          ...                                                ...
# 1871         617                          Villa de luxe Dar Bouazza
# 1872         618             Appartement meublée alliance bab sebta
# 1874         620                   Appartement à 50 m des Sœurettes
# 1875         621               Opportunité à saisir sur Dar Bouazza
# 1878         624                    Vente appartement haut standing
#
#                            Location         Price  \
# 0                         Bouskoura  7 800 000 DH
# ...

# %%
# Find Outlier
Q1 = all_data.quantile(0.25)
Q3 = all_data.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
print(all_data < (Q1 - 1.5 * IQR)) |(all_data > (Q3 + 1.5 * IQR))
# Out:
# Unnamed: 0           310.5
# Prix             2840000.0
# outside              241.5
# Price/Surface       8048.5
# dtype: float64
# C:\Users\Pro\AppData\Local\Temp\ipykernel_12736\1074037713.py:6: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   print(all_data < (Q1 - 1.5 * IQR)) |(all_data > (Q3 + 1.5 * IQR))
# C:\Users\Pro\AppData\Local\Temp\ipykernel_12736\1074037713.py:6: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   print(all_data < (Q1 - 1.5 * IQR)) |(all_data > (Q3 + 1.5 * IQR))
#       Caractéristiques   City  Description  Location  Pictures  Pieces  Price  \
# ...

# %%
#Remove Outlier
all_data = all_data[~((all_data < (Q1 - 1.5 * IQR)) |(all_data > (Q3 + 1.5 * IQR))).any(axis=1)]
all_data.shape

# %%
# all_data['City'] = all_data['Location'].apply(lambda x: x.split("à")[0])
# all_data['City']

# %%
# all_data['Location'].str.contains('à')

# if all_data['Location'].isin(['à']) == True:
# # for a in all_data['Location']:
# #     print('à' in set(a['Location']))

# %%
# def nmbr_bathroom(data):
#     if len(data.split(' '))>1:
#         if (data.split('  ')[1]) == "Chambre" or (data.split(' ')[1]) == "Chambres":
#             return data
#         else:
#             return None
#     else:
#         return None
        
# data["Nmbr of rooms"] = all_data["Pieces"].apply(lambda x : nmbr_bathroom(x[2]))

# %%
import matplotlib.pyplot as plt

###
city_name=all_data['City'].value_counts().index
city_val=all_data['City'].value_counts().values
#top 6 citys
plt.pie(city_val[:10],labels=city_name[:10],autopct='%1.2f%%')
#
plt.bar(keys,city_val.count()['Prix'])
plt.rcParams['figure.figsize'] = (10,6)
plt.xticks(keys, rotation='vertical', size=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 9>()
#       7 plt.pie(city_val[:10],labels=city_name[:10],autopct='%1.2f%%')
#       8 #
# ----> 9 plt.bar(keys,city_val.count()['Prix'])
#      10 plt.rcParams['figure.figsize'] = (10,6)
#      11 plt.xticks(keys, rotation='vertical', size=10)
#
# NameError: name 'keys' is not defined

# %%
import matplotlib.pyplot as plt

keys = [city for city, df in all_data.groupby(['City'])]

plt.bar(keys,all_data.groupby(['City']).sum()['Prix'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('City name')
plt.rcParams['figure.figsize'] = (20,10)
plt.xticks(keys, rotation='vertical', size=20)
plt.show()

# %%
import matplotlib.pyplot as plt

keys = [city for city, df in all_data.groupby(['Price/surface'])]

plt.bar(keys,all_data.groupby(['Prix']).sum()['Prix'])
plt.ylabel('Sales in USD ($)')
plt.xlabel('City name')
plt.rcParams['figure.figsize'] = (20,10)
plt.xticks(keys, rotation='vertical', size=20)
plt.show()

# %%
# Importing Dependencies
import pandas as pd
import matplotlib.pyplot as plt


#Add custom entries here
custom_df = all_data.loc[all_data['City'].isin([''])]

# Create new df
new_df = pd.concat([all_data[:10], all_data[-10:], custom_df])
new_df.sort_values(by=['Prix'], inplace= True)
new_df.reset_index(drop=True, inplace= True)

# Creating the bar plot
plt.bar(new_df['City'], new_df['Prix'])
plt.xticks(rotation=90) 
plt.xlabel("City")
plt.ylabel("Prix") 
plt.rcParams['figure.figsize'] = (10,6)

plt.show()

# %%
import matplotlib.pyplot as plt

###
city_name=all_data['outside'].value_counts().index
city_val=all_data['outside'].value_counts().values
#top 6 citys
plt.pie(city_val[:10],labels=city_name[:10],autopct='%1.2f%%')
#
plt.bar(keys,city_val.count()['Prix'])
plt.rcParams['figure.figsize'] = (10,6)
plt.xticks(keys, rotation='vertical', size=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 9>()
#       7 plt.pie(city_val[:10],labels=city_name[:10],autopct='%1.2f%%')
#       8 #
# ----> 9 plt.bar(keys,city_val.count()['Prix'])
#      10 plt.rcParams['figure.figsize'] = (10,6)
#      11 plt.xticks(keys, rotation='vertical', size=10)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
keys = [pair for pair, df in all_data.groupby(['outside'])]

plt.plot(keys, all_data.groupby(['outside']).count()['Prix'])
plt.xticks(keys)
plt.grid()
plt.rcParams['figure.figsize'] = (30,8)
# plt.figure(figsize=(100,100))
plt.show()

# %%
# Importing Dependencies
import pandas as pd
import matplotlib.pyplot as plt


#Add custom entries here
custom_df = all_data.loc[all_data['outside'].isin([' '])]

# Create new df
new_df = pd.concat([all_data[:10], all_data[-10:], custom_df])
new_df.sort_values(by=['Prix'], inplace= True)
new_df.reset_index(drop=True, inplace= True)

# Creating the bar plot
plt.bar(new_df['outside'], new_df['Prix'])
plt.xticks(rotation=90) 
plt.xlabel("surface par m2")
plt.ylabel("Price") 
plt.rcParams['figure.figsize'] = (10,6)
plt.show()

# %%
# Price / Surface  #xhal % dtaman dl m2 fl maghreb#
import matplotlib.pyplot as plt

###
city_name=all_data['Price/Surface'].value_counts().index
city_val=all_data['Price/Surface'].value_counts().values
#top 6 citys
plt.pie(city_val[:10],labels=city_name[:10],autopct='%1.2f%%')
#
# plt.bar(keys,city_val.count()['Price/Surface'])
plt.rcParams['figure.figsize'] = (10,6)
plt.xticks(keys, rotation='vertical', size=10)
plt.show()

# %%
# Importing Dependencies
import pandas as pd
import matplotlib.pyplot as plt


#Add custom entries here
custom_df = all_data.loc[all_data['City'].isin([' '])]

# Create new df
new_df = pd.concat([all_data[:10], all_data[-10:], custom_df])
new_df.sort_values(by=['Price/Surface'], inplace= True)
new_df.reset_index(drop=True, inplace= True)

# Creating the bar plot
plt.bar(new_df['City'], new_df['Price/Surface'])
plt.xticks(rotation=90) 
plt.xlabel("City")
plt.ylabel("Price/Surface") 
plt.rcParams['figure.figsize'] = (10,6)
plt.show()

# %%
# all_data.drop(all_data[all_data['City'] == ''].index, inplace = True)
# all_data.drop(all_data[all_data['City'] == ' '].index, inplace = True)
# all_data['City'].count()
# all_data

# %%
print(all_data.groupby(['City']).count())
# Out:
#             Unnamed: 0  Title  Location  Price  Caractéristiques  Pieces  \
# City
# Agadir              61     61        61     61                61      61
# AinAttig             1      1         1      1                 1       1
# AitMelloul           3      3         3      3                 3       3
# AlHoceima            3      3         3      3                 3       3
# Anjra                1      1         1      1                 1       1
# ...                ...    ...       ...    ...               ...     ...
# Tiznit               2      2         2      2                 2       2
# TnineAglou           1      1         1      1                 1       1
# Tétouan              7      7         7      7                 7       7
# ValFleury            1      1         1      1                 1       1
# Zenata               5      5         5      5                 5       5
#
#             Description  Pictures  Télephone  Surface  Prix  outside  \
# City
# ...

# %%
import seaborn as sns

# %%
# Create new df
new_df = pd.concat([all_data[:10], all_data[-10:], custom_df])
new_df.sort_values(by=['Prix'], inplace= True)
new_df.reset_index(drop=True, inplace= True)
sns.scatterplot(x=new_df['City'], y=new_df['Prix']);

# %%
new_df = pd.concat([all_data[:10], all_data[-10:], custom_df])
new_df.sort_values(by=['Prix'], inplace= True)
new_df.reset_index(drop=True, inplace= True)
sns.jointplot(x=new_df['City'], y=new_df['Prix']);

# %%
df_area_workout = all_data.groupby(['City'])['Prix'].count().reset_index()
df_area_workout_pivot = df_area_workout.pivot(index='Prix', columns='City', values='Prix').fillna(0)
sns.heatmap(df_area_workout_pivot, annot=True, fmt='.0f', cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='City', ylabel='Prix'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# Load the example flights dataset and convert to long-form
# flights_long = sns.load_dataset("flights")
flights = all_data.pivot("City", "Price/Surface", "Prix")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 7>()
#       3 sns.set_theme()
#       5 # Load the example flights dataset and convert to long-form
#       6 # flights_long = sns.load_dataset("flights")
# ----> 7 flights = all_data.pivot("City", "Price/Surface", "Prix")
#       9 # Draw a heatmap with the numeric values in each cell
#      10 f, ax = plt.subplots(figsize=(9, 6))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:7870, in DataFrame.pivot(self, index, columns, values)
#    7865 @Substitution("")
#    7866 @Appender(_shared_docs["pivot"])
#    7867 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7868     from pandas.core.reshape.pivot import pivot
# -> 7870     return pivot(self, index=index, columns=columns, values=values)
#
# ...

# %%
fig,ax = plt.subplots(2,2,figsize=(10,9))
sale_price = all_data['Prix'].values


ax[0,0].scatter(all_data['outside'],sale_price)
ax[0,0].set_title('Outside vs SalePrice')
ax[0,1].scatter(all_data['City'],sale_price)
ax[0,1].set_title('City vs SalePrice')
ax[1,0].scatter(all_data['Price/Surface'],sale_price)
ax[1,0].set_title('Price/Surface vs SalePrice')
plt.tight_layout()

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.distplot(all_data['outside'],kde=False,ax=ax)
plt.title('Sale Price Distribution')
plt.xlabel('Sale Price')
plt.ylabel('Freq')
# Out:
# C:\Users\Pro\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Freq')

# %%
fig,ax = plt.subplots(figsize=(8,6))
correlation = all_data.select_dtypes(include=['float64','int64']).iloc[:,1:].corr()
sns.heatmap(correlation,ax=ax,vmax=1,square=True)
plt.title('Numeric Feature heatmap')
# Out:
# Text(0.5, 1.0, 'Numeric Feature heatmap')

# %%
fig,ax = plt.subplots(figsize=(8,6))
sns.regplot(x = 'outside', y='Prix' , data=all_data,ax=ax)
# Out:
# <AxesSubplot:xlabel='outside', ylabel='Prix'>

# %%
fig = plt.figure(2,figsize=(10,6))
plt.subplot(211)
plt.scatter(all_data['outside'].values,sale_price)
plt.title('Surface vs SalePrice')
plt.subplot(212)
plt.scatter(all_data['Price/Surface'].values,sale_price)
plt.title('Price/Surface vs SalePrice')
plt.tight_layout()

# %%
fig,ax = plt.subplots(figsize=(18,6))
sns.boxplot(x = 'outside', y = 'Prix',  data = all_data,ax=ax)
plt.title('outside vs SalePrice')
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %%
# calculate Q1 and Q3
Q1 = all_data.quantile(0.25)
Q3 = all_data.quantile(0.75)

# calculate the IQR
IQR = Q3 - Q1

# filter the dataset with the IQR
IQR_outliers = all_data[((all_data < (Q1 - 1.5 * IQR)) |(all_data > (Q3 + 1.5 * IQR))).any(axis=1)]
IQR_outliers
# Out:
# C:\Users\Pro\AppData\Local\Temp\ipykernel_2444\2736507226.py:9: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   IQR_outliers = all_data[((all_data < (Q1 - 1.5 * IQR)) |(all_data > (Q3 + 1.5 * IQR))).any(axis=1)]
#       Unnamed: 0                                              Title  \
# 0              0    Villa sur prestigia 570m² ville verte bouskoura
# 21            21       Penthouse à vendre à l’Orangeraie du Souissi
# 53            53                              Villa de 400 m² Anfa:
# 77            77                    Vente Appartement Rabat Souissi
# 102          102  Maison de luxe à vendre à Route Casablanca. 6 ...
# ...          ...                                                ...
# 1818         564        Belle villa vide à vendre à Targa Marrakech
# ...

# %%
df = all_data[~((all_data < (Q1 - 1.5 * IQR)) |(all_data > (Q3 + 1.5 * IQR))).any(axis=1)]
# Out:
# C:\Users\Pro\AppData\Local\Temp\ipykernel_2444\1296440571.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   df = all_data[~((all_data < (Q1 - 1.5 * IQR)) |(all_data > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
fig = plt.figure(2,figsize=(10,6))
plt.subplot(211)
plt.scatter(all_data['outside'].values,sale_price)
plt.title('Surface vs SalePrice')
plt.subplot(212)
plt.scatter(all_data['Price/Surface'].values,sale_price)
plt.title('Price/Surface vs SalePrice')
plt.tight_layout()

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(all_data['Prix'])
plt.subplot(1,2,2)
sns.distplot(all_data['outside'])
plt.show()

# %%
sns.boxplot(all_data['Prix'])
# Out:
# <AxesSubplot:xlabel='Prix'>

# %%
import numpy as np
print(np.where(all_data['Prix']>1))
# Out:
# (array([   0,    1,    2, ..., 1307, 1308, 1309], dtype=int64),)

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(all_data['Prix'], all_data['outside'])
 
# x-axis label
ax.set_xlabel('(Proportion non-retail business acres)/(town)')
 
# y-axis label
ax.set_ylabel('(Full-value property-tax rate)/( $10,000)')
plt.show()

# %%
#  # Storing in Excel File   
all_data.to_excel("/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Vente/Line_Chart.xlsx")

# %%
from scipy import stats
import numpy as np
 
z = np.abs(stats.zscore(all_data['Prix']))
print(z)
# Out:
# 0       3.692344
# 1       0.047009
# 2       0.058098
# 3       0.729199
# 4       0.304133
#           ...
# 1871    3.199513
# 1872    0.897142
# 1874    0.365737
# 1875    0.065490
# 1878    0.422792
# Name: Prix, Length: 1310, dtype: float64

# %%
threshold = 3
 
# Position of the outlier
print(np.where(z > 3))
# Out:
# (array([   0,   14,   38,  124,  140,  141,  179,  185,  241,  312,  327,
#         328,  525,  527,  567,  593,  644,  674,  744,  908,  963, 1095,
#        1104, 1142, 1149, 1284, 1305], dtype=int64),)

# %%
# IQR
Q1 = np.percentile(all_data['Prix'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(all_data['Prix'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
print(IQR)
# Out:
# 1810650.0

# %%
# Above Upper bound
upper = all_data['Prix'] >= (Q3+1.5*IQR)
 
print("Upper bound:",upper)
# print(np.where(upper))
 
# Below Lower bound
lower = all_data['Prix'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
# print(np.where(lower))
# Out:
# Upper bound: 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1871     True
# 1872    False
# 1874    False
# 1875    False
# 1878    False
# Name: Prix, Length: 1310, dtype: bool
# Lower bound: 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1871    False
# 1872    False
# 1874    False
# 1875    False
# 1878    False
# Name: Prix, Length: 1310, dtype: bool

# %%
# Importing
import sklearn
import pandas as pd
 
 
# Detection 
# IQR
Q1 = np.percentile(all_data['Prix'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(all_data['Prix'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1

print("Old Shape: ",all_data.shape)
 
# Upper bound
upper = np.where(all_data['Prix'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(all_data['Prix'] <= (Q1-1.5*IQR))

# Removing the Outliers '''
all_data.drop(upper[0], inplace = True)
all_data.drop(lower[0], inplace = True)
 
print("New Shape: ", all_data.shape)
# Out:
# Old Shape:  (1310, 14)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [64], in <cell line: 23>()
#      20 lower = np.where(all_data['Prix'] <= (Q1-1.5*IQR))
#      22 # Removing the Outliers '''
# ---> 23 all_data.drop(upper[0], inplace = True)
#      24 all_data.drop(lower[0], inplace = True)
#      26 print("New Shape: ", all_data.shape)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
