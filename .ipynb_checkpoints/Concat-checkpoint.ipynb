# %%
import os
import pandas as pd #pip install pandas

# %%
df1 = pd.read_excel(r'/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Vente/mubawabVente1-20_clean.xlsx')
df2 = pd.read_excel(r'/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Vente/mubawabVente21-40_clean.xlsx')
df3 = pd.read_excel(r'/Users/Pro/Desktop/EtlProject_Web-Scraping/Mubawab_Vente/mubawabVente41-60_clean.xlsx')
# df1.drop(columns=['Unnamed: 0', 'Unnamed: 1'])
df1
# Out:
#      Unnamed: 0  Unnamed: 1  \
# 0             0         NaN
# 1             1         NaN
# 2             2         NaN
# 3             3         NaN
# 4             4         NaN
# ..          ...         ...
# 622         622         NaN
# 623         623         NaN
# 624         624         NaN
# 625         625         NaN
# 626         626         NaN
#
#                                                  Title  \
# 0      Villa sur prestigia 570m² ville verte bouskoura
# 1              Appartement 132m² aux portes californie
# 2    Appartement de 122m² en vente, Le Prestige Cal...
# 3    Top affaire magnifique villa a vendre a Agdal ...
# 4       Les deux appartements à vendre à Hay Al Riyadh
# ..                                                 ...
# 622  Top affaire villa plein pied a vendre sur la r...
# 623  Top affaire vente villa proche de la mer dar b...
# 624  Opportunité a saisir trés bel appartement a ve...
# 625                               Beau duplex a vendre
# ...

# %%
values1 = df1[['Title','Location','Price','Caractéristiques','Pieces','Description','Pictures','Télephone','Surface']]
values2 = df2[['Title','Location','Price','Caractéristiques','Pieces','Description','Pictures','Télephone','Surface']]
values3 = df3[['Title','Location','Price','Caractéristiques','Pieces','Description','Pictures','Télephone','Surface']]

dataframes = [values1,values2,values3]
join = pd.concat(dataframes)
join.to_excel("ouput.xlsx")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 values1 = df1[['Title','Location','Price','Caractéristiques','Pieces','Description','Pictures','Télephone','Surface']]
#       2 values2 = df2[['Title','Location','Price','Caractéristiques','Pieces','Description','Pictures','Télephone','Surface']]
#       3 values3 = df3[['Title','Location','Price','Caractéristiques','Pieces','Description','Pictures','Télephone','Surface']]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# ...
